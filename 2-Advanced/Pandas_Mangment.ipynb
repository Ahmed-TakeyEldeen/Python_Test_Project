# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r'D:\SQL EXCEL\data_jobs.csv')
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.sample(5)
# Out:
#               job_title_short                            job_title  \
# 554054          Data Engineer              GCP Cloud Data Engineer
# 644487           Data Analyst                         Data Analyst
# 276592           Data Analyst                         Data Analyst
# 556232  Senior Data Scientist            Sr. Data Scientist-Remote
# 388525       Business Analyst  Business Analyst Customer Solutions
#
#              job_location                  job_via job_schedule_type  \
# 554054       Dearborn, MI               via Indeed         Full-time
# 644487        Netherlands             via LinkedIn         Full-time
# 276592             Mexico                via BeBee         Full-time
# 556232        Phoenix, AZ          via IT JobServe         Full-time
# 388525  Brussels, Belgium  via Emplois Trabajo.org         Full-time
#
#         job_work_from_home            search_location      job_posted_date  \
# ...

# %%
df.index.name= 'job_name'

# %%
df.sample(7)
# Out:
#                     job_title_short  \
# job_name
# 540391                 Data Analyst
# 654023                Data Engineer
# 604960    Machine Learning Engineer
# 270475               Data Scientist
# 722109               Data Scientist
# 228286                Data Engineer
# 60117                  Data Analyst
#
#                                           job_title  \
# job_name
# 540391                               Data Analytics
# 654023                      Data Hydration Engineer
# 604960     AI Research Scientist – Object Detection
# 270475                          Profesor/a Big Data
# 722109                             Research Analyst
# 228286                          Cloud Data Engineer
# 60117     Data Quality Lead/ Data Analyst /SQL/Bank
#
#                                       job_location               job_via  \
# job_name
# 540391                                     Denmark     via BeBee Danmark
# ...

# %%
df_usa = df[df['job_country']=='United Kingdom'].reset_index()

# %%
df_usa.set_index('job_title')
# Out:
#                                                     job_name  \
# job_title
# Data Engineer                                             15
# Senior Data Analyst                                       45
# Data Entry/Economic Data Analyst                          74
# Systems & Data Analyst - Exploitation, Missing ...        97
# Data Science Team Lead                                   152
# ...                                                      ...
# Data Quality Analyst                                  785485
# Data Scientist                                        785513
# Lead Data Engineer                                    785522
# Submission for the position: Data Engineer Seni...    785642
# Senior Data Scientist                                 785676
#
#                                                           job_title_short  \
# job_title
# Data Engineer                                               Data Engineer
# ...

# %%
median_pivot = df_usa.pivot_table(values='salary_year_avg',index='job_title_short',aggfunc=['min','max','median'])

# %%
median_pivot
# Out:
#                                       min             max          median
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  30000.0         73500.0         56700.0
# Data Analyst                      30000.0        180000.0         87750.0
# Data Engineer                     35000.0        249000.0        110000.0
# Data Scientist                    33488.5        205000.0        105300.0
# Machine Learning Engineer         85205.0        200000.0        149653.0
# Senior Data Analyst               79200.0        118140.0        111175.0
# Senior Data Engineer              45000.0        171620.0        147500.0
# Senior Data Scientist             72500.0        170575.0        157500.0
# Software Engineer                 89100.0        160000.0         89100.0

# %%
median_pivot.sort_index(inplace=True)

# %%
median_pivot
# Out:
#                                       min             max          median
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  30000.0         73500.0         56700.0
# Data Analyst                      30000.0        180000.0         87750.0
# Data Engineer                     35000.0        249000.0        110000.0
# Data Scientist                    33488.5        205000.0        105300.0
# Machine Learning Engineer         85205.0        200000.0        149653.0
# Senior Data Analyst               79200.0        118140.0        111175.0
# Senior Data Engineer              45000.0        171620.0        147500.0
# Senior Data Scientist             72500.0        170575.0        157500.0
# Software Engineer                 89100.0        160000.0         89100.0

# %%
median_pivot.sort_values(by='job_title_short',ascending=False)
# Out:
#                                       min             max          median
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Software Engineer                 89100.0        160000.0         89100.0
# Senior Data Scientist             72500.0        170575.0        157500.0
# Senior Data Engineer              45000.0        171620.0        147500.0
# Senior Data Analyst               79200.0        118140.0        111175.0
# Machine Learning Engineer         85205.0        200000.0        149653.0
# Data Scientist                    33488.5        205000.0        105300.0
# Data Engineer                     35000.0        249000.0        110000.0
# Data Analyst                      30000.0        180000.0         87750.0
# Business Analyst                  30000.0         73500.0         56700.0
