# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\speedlink\Downloads\csv python test\Companies.csv')
#, header =None ,names =[11,12,13,14,15,16,17]
df
# Out:
#      Rank                                 Name  \
# 0       1                              Walmart
# 1       2                               Amazon
# 2       3                           ExxonMobil
# 3       4                                Apple
# 4       5                   UnitedHealth Group
# 5       6                           CVS Health
# 6       7                   Berkshire Hathaway
# 7       8                             Alphabet
# 8       9                 McKesson Corporation
# 9      10                  Chevron Corporation
# 10     11                              Cencora
# 11     12                               Costco
# 12     13                            Microsoft
# 13     14                      Cardinal Health
# 14     15                                Cigna
# 15     16                   Marathon Petroleum
# 16     17                          Phillips 66
# 17     18                        Valero Energy
# 18     19                   Ford Motor Company
# ...

# %%
#df = pd.read_csv(r'C:\Users\speedlink\Downloads\csv python test\real_estate.csv' )

#df = pd.read_table(r'C:\Users\speedlink\Downloads\csv python test\real_estate.csv', sep= ',')

# pd.read  table ,csv ,json ,txt ,excel 

df = pd.read_excel(r'C:\Users\speedlink\Downloads\csv python test\Lambda Functions.xlsx',sheet_name= 'Example')

df
# Out:
#     Unnamed: 0                     Unnamed: 1           January  February  \
# 0          NaN      SAT Prep High School Book               439       114
# 1          NaN    SAT Prep Middle School Book               154       248
# 2          NaN  SAT Personal Tutoring Session                88        95
# 3          NaN           Ace The SAT Bootcamp               376       239
# 4          NaN   College Admission Counseling                12         5
# 5          NaN               SAT Test Booklet               285       480
# 6          NaN                            NaN               NaN       NaN
# 7          NaN                            NaN               NaN       NaN
# 8          NaN                January Formula  January Function  February
# 9          NaN      SAT Prep High School Book               NaN       NaN
# 10         NaN           Ace The SAT Bootcamp               NaN       NaN
# 11         NaN               SAT Test Booklet               NaN       NaN
# ...

# %%
pd.set_option('display.max.rows',2000)
pd.set_option('display.max.columns',2000)
