# %%
import random 
import statistics
import numpy as np

random.randint(10,15)
# Out:
# 15

# %%
new_list = []



for x in range(1000000):
    new_list.append(random.randint(50000,100000))

new_list
# Out:
# [72419,
#  58477,
#  61397,
#  98125,
#  80059,
#  62820,
#  75342,
#  88709,
#  57975,
#  52561,
#  62072,
#  87920,
#  86602,
#  93782,
#  75958,
#  81546,
#  68427,
#  52793,
#  59590,
#  51540,
#  78461,
#  61451,
#  67114,
#  61193,
#  65917,
#  77102,
#  79081,
#  51082,
#  56498,
#  90988,
#  73136,
#  67083,
#  86172,
#  94252,
#  61449,
#  99316,
#  95282,
#  64376,
#  97321,
#  79598,
#  85177,
#  68028,
#  52702,
#  56462,
#  70078,
#  59237,
#  78316,
#  79440,
#  68159,
#  97022,
#  67888,
#  60813,
#  83502,
#  72833,
#  93002,
#  85762,
#  68054,
#  89361,
#  67627,
#  82151,
#  52854,
#  88458,
#  65336,
#  72784,
#  79232,
#  52192,
#  68863,
#  61302,
#  80422,
#  56555,
#  77981,
#  54474,
#  69333,
#  87551,
#  58041,
#  68817,
#  62338,
#  96299,
#  85918,
#  67886,
#  59665,
#  71824,
#  76814,
#  72190,
#  76896,
#  65362,
#  70376,
#  92334,
#  90524,
#  80814,
#  83073,
#  99217,
#  90194,
#  54897,
#  96673,
#  67812,
#  65764,
#  65835,
#  70833,
#  81678,
# ...

# %%
# %%timeit

statistics.mean(new_list)
# Out:
# 288 ms ± 3.16 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit

np.mean(new_list)
# Out:
# 51.9 ms ± 322 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
my_array = np.array([10,20,30,45])

# %%
job_titles = np.array(['data_analyst','data_engineer','data_scientst','data_warehouse','data_com'])

job_salaries = np.array([80000,100000,95000,75000,np.nan])

job_bounes = np.array([.2,.15,.17,.25,np.nan])


new_total = job_salaries * (1+job_bounes)

new_total
# Out:
# array([ 96000., 115000., 111150.,  93750.,     nan])

# %%
np.nanmean(new_total)
# Out:
# 103975.0
