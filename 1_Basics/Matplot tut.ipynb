# %%
import pandas as pd 
import datetime as dt
import matplotlib.pyplot as plt

df= pd.read_csv(r'D:\SQL EXCEL\data_jobs.csv')

df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
x = [1,2,3,4]
y = [2,5,10,20]

plt.plot(x,y)
plt.show()

# %%
date_counts = df.job_posted_date.value_counts()

date_counts = date_counts.sort_index()

date_counts
# Out:
# job_posted_date
# 2023-01-01 00:00:04    1
# 2023-01-01 00:00:07    1
# 2023-01-01 00:00:22    1
# 2023-01-01 00:00:24    1
# 2023-01-01 00:00:27    1
#                       ..
# 2023-12-31 23:40:18    2
# 2023-12-31 23:40:22    2
# 2023-12-31 23:40:31    2
# 2023-12-31 23:40:32    1
# 2023-12-31 23:59:58    2
# Name: count, Length: 607192, dtype: int64

# %%
plt.plot(date_counts.index, date_counts)

# %%
df['job_posted_month'] = df['job_posted_date']

# %%
print(df['job_posted_month'].dtype)
# Out:
# int32

# %%
df['job_posted_month'] = pd.to_datetime(df['job_posted_month'])

# %%
df['job_posted_month'] = df['job_posted_month'].dt.month

df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
monthly_counts = df.job_posted_month.value_counts()

monthly_counts.sort_index()

monthly_counts
# Out:
# job_posted_month
# 1     91822
# 8     75162
# 10    66611
# 2     64578
# 11    64450
# 3     64084
# 7     63777
# 4     62919
# 9     62359
# 6     61572
# 12    56303
# 5     52104
# Name: count, dtype: int64

# %%
plt.plot(monthly_counts.index ,monthly_counts.values)

# %%
value_counts = df.job_title_short.value_counts()

value_counts
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
plt.bar(value_counts.index , value_counts)
# Out:
# <BarContainer object of 10 artists>

# %%
value_counts = value_counts.sort_values(ascending=True)

plt.barh(value_counts.index , value_counts)

plt.show()

# %%
value_counts.sort_index(ascending= True)
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# Name: count, dtype: int64

# %%
value_counts = df.job_title_short.value_counts()

plt.bar(value_counts.index,value_counts)

plt.ylabel('count_of_job_posting')
plt.xlabel('data_jobs')
plt.xticks(rotation= 45, ha='right')
plt.yticks(rotation= 45)

plt.title('job_title_short')
# Out:
# Text(0.5, 1.0, 'job_title_short')
