# %%
import ast
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r'D:\SQL EXCEL\data_jobs.csv')
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x : ast.literal_eval(x) if pd.notna(x) else x)
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')]
df_US= df_US.dropna(subset='salary_year_avg')
df_US
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 782637    Data Analyst                     Data Integration Analyst
# 782798    Data Analyst                       Reference Data Analyst
# 783588    Data Analyst                       Data Analytics Manager
# 783866    Data Analyst              Lead Credit Bureau Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
#
#               job_location                job_via job_schedule_type  \
# 109               Anywhere             via Get.It         Full-time
# ...

# %%
df_US_exp= df_US.explode('job_skills')
df_US_exp
# Out:
#        job_title_short                              job_title   job_location  \
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 180       Data Analyst                       Data Analyst III  Dos Palos, CA
# ...                ...                                    ...            ...
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
#
# ...

# %%
df_skills= df_US_exp.groupby(by='job_skills')['salary_year_avg'].agg(['count','median']).sort_values(by='count',ascending=False)
df_skills = df_skills.rename(columns={'count': 'skill_count','median': 'median_salary'})
df_len = len(df_US)
df_skills['skill_percent'] = df_skills['skill_count']/df_len * 100

skill_percent = 5

df_high_demand_skills = df_skills[df_skills['skill_percent'] >5]

df_high_demand_skills
# Out:
#             skill_count  median_salary  skill_percent
# job_skills
# sql                2508       91000.00      57.655172
# excel              1808       84392.00      41.563218
# python             1431       97500.00      32.896552
# tableau            1364       92875.00      31.356322
# sas                 926       90000.00      21.287356
# r                   893       92500.00      20.528736
# power bi            838       90000.00      19.264368
# powerpoint          462       85000.00      10.620690
# word                461       81194.75      10.597701
# sql server          286       92500.00       6.574713
# oracle              274       96923.75       6.298851
# go                  224       90000.00       5.149425

# %%
from adjustText import adjust_text

df_high_demand_skills.plot(kind='scatter', x='skill_percent',y='median_salary')
plt.tight_layout()
sns.despine()
plt.title('Top 10 optimal skills for Data Analyst')
texts=[]

for i , txt in enumerate(df_high_demand_skills.index):
    texts.append(plt.text(df_high_demand_skills['skill_percent'].iloc[i],df_high_demand_skills['median_salary'].iloc[i],txt))

adjust_text(texts,arrowprops=dict(arrowstyle='->',color='gray'))

ax =plt.gca()
ax.xaxis.set_major_formatter(lambda x ,_ : f'{int(x)}%')
ay= plt.gca()
ay.yaxis.set_major_formatter(lambda y ,_ : f'{int(y/1000)}K')
plt.xlabel('Skill Percentage')
plt.ylabel('Median Salary(USD)')
plt.show()

# %%
df_technology = df['job_type_skills'].copy()

df_technology = df_technology.drop_duplicates()

df_technology = df_technology.dropna()

technology_dict = {}

for row in df_technology:
    row_dict = ast.literal_eval(row)
    for key ,value in row_dict.items():
        if key in technology_dict:
            technology_dict[key] += value
        else:
            technology_dict[key] = value

for key , value in technology_dict.items():
    technology_dict[key] = list(set(value))

technology_dict
# Out:
# {'analyst_tools': ['outlook',
#   'word',
#   'powerbi',
#   'sas',
#   'cognos',
#   'sharepoint',
#   'power bi',
#   'nuix',
#   'visio',
#   'msaccess',
#   'sap',
#   'ssis',
#   'powerpoint',
#   'tableau',
#   'alteryx',
#   'spss',
#   'qlik',
#   'datarobot',
#   'dax',
#   'esquisse',
#   'looker',
#   'microstrategy',
#   'excel',
#   'sheets',
#   'splunk',
#   'spreadsheet',
#   'ms access',
#   'ssrs'],
#  'programming': ['sass',
#   'sas',
#   'nosql',
#   'bash',
#   'visual basic',
#   'no-sql',
#   'crystal',
#   'erlang',
#   'vb.net',
#   'python',
#   'powershell',
#   'vba',
#   'golang',
#   't-sql',
#   'javascript',
#   'kotlin',
#   'julia',
#   'fortran',
#   'elixir',
#   'matlab',
#   'perl',
#   'mongo',
#   'c#',
#   'objective-c',
#   'mongodb',
#   'cobol',
#   'delphi',
#   'pascal',
#   'html',
#   'php',
#   'rust',
#   'assembly',
#   'groovy',
#   'dart',
#   'r',
#   'apl',
#   'clojure',
#   'haskell',
#   'c++',
#   'ocaml',
#   'typescript',
# ...

# %%
technology_dict = pd.DataFrame(list(technology_dict.items()),columns=['technology','skills'])
technology_dict
# Out:
#       technology                                             skills
# 0  analyst_tools  [outlook, word, powerbi, sas, cognos, sharepoi...
# 1    programming  [sass, sas, nosql, bash, visual basic, no-sql,...
# 2          cloud  [linode, gcp, watson, databricks, ovh, digital...
# 3      libraries  [seaborn, spring, hugging face, flutter, gdpr,...
# 4          other  [chef, github, git, puppet, terminal, homebrew...
# 5      databases  [sqlserver, sqlite, dynamodb, neo4j, redis, ca...
# 6             os  [windows, kali, centos, macos, redhat, ubuntu,...
# 7          async  [asana, wimi, clickup, trello, wrike, jira, no...
# 8  webframeworks  [vue.js, express, asp.net, fastapi, ruby on ra...
# 9           sync  [microsoft teams, zoom, twilio, ringcentral, w...

# %%
technology_dict = technology_dict.explode('skills')
technology_dict
# Out:
#        technology      skills
# 0   analyst_tools     outlook
# 0   analyst_tools        word
# 0   analyst_tools     powerbi
# 0   analyst_tools         sas
# 0   analyst_tools      cognos
# ..            ...         ...
# 9            sync        wire
# 9            sync    symphony
# 9            sync       unify
# 9            sync  rocketchat
# 9            sync  mattermost
#
# [256 rows x 2 columns]

# %%
df_plot= df_high_demand_skills.merge(technology_dict,left_on='job_skills',right_on='skills')
df_plot
# Out:
#     skill_count  median_salary  skill_percent     technology      skills
# 0          2508       91000.00      57.655172    programming         sql
# 1          1808       84392.00      41.563218  analyst_tools       excel
# 2          1431       97500.00      32.896552    programming      python
# 3          1364       92875.00      31.356322  analyst_tools     tableau
# 4           926       90000.00      21.287356  analyst_tools         sas
# 5           926       90000.00      21.287356    programming         sas
# 6           893       92500.00      20.528736    programming           r
# 7           838       90000.00      19.264368  analyst_tools    power bi
# 8           462       85000.00      10.620690  analyst_tools  powerpoint
# 9           461       81194.75      10.597701  analyst_tools        word
# 10          286       92500.00       6.574713      databases  sql server
# 11          274       96923.75       6.298851          cloud      oracle
# ...

# %%
from adjustText import adjust_text

#df_high_demand_skills.plot(kind='scatter', x='skill_percent',y='median_salary')
sns.scatterplot(
    data=df_plot,
    x='skill_percent',
    y='median_salary',
    hue='technology'
)
plt.tight_layout()
sns.despine()
plt.title('Top 10 optimal skills for Data Analyst')
texts=[]

for i , txt in enumerate(df_high_demand_skills.index):
    texts.append(plt.text(df_high_demand_skills['skill_percent'].iloc[i],df_high_demand_skills['median_salary'].iloc[i],txt))

adjust_text(texts,arrowprops=dict(arrowstyle='->',color='gray'))

ax =plt.gca()
ax.xaxis.set_major_formatter(lambda x ,_ : f'{int(x)}%')
ay= plt.gca()
ay.yaxis.set_major_formatter(lambda y ,_ : f'{int(y/1000)}K')
plt.xlabel('Skill Percentage')
plt.ylabel('Median Salary(USD)')
plt.show()
